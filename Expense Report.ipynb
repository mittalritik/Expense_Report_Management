# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

FILE_NAME = "expenses.csv"

# Create file if not exists
if not os.path.exists(FILE_NAME):
    df = pd.DataFrame(columns=["Date", "Category", "Amount", "Description"])
    df.to_csv(FILE_NAME, index=False)


def add_expense():
    try:
        date = input("Enter date (YYYY-MM-DD): ")
        category = input("Enter category (Food, Travel, Shopping, etc): ")
        amount = float(input("Enter amount: "))
        description = input("Enter description: ")

        df = pd.read_csv(FILE_NAME)

        new_expense = pd.DataFrame({
            "Date": [date],
            "Category": [category],
            "Amount": [amount],
            "Description": [description]
        })

        df = pd.concat([df, new_expense], ignore_index=True)
        df.to_csv(FILE_NAME, index=False)

        print("Expense added successfully!")

    except ValueError:
        print("Invalid amount entered.")


def view_expenses():
    df = pd.read_csv(FILE_NAME)

    if df.empty:
        print("No expenses found.")
    else:
        print("\nAll Expenses")
        print(df)


def delete_expense():
    df = pd.read_csv(FILE_NAME)

    if df.empty:
        print("No expenses to delete.")
        return

    print(df)

    try:
        index = int(input("Enter index to delete: "))
        df = df.drop(index)
        df.to_csv(FILE_NAME, index=False)
        print("Expense deleted.")

    except:
        print("Invalid index.")


def generate_report():
    df = pd.read_csv(FILE_NAME)

    if df.empty:
        print("No data available.")
        return

    total = df["Amount"].sum()
    print("\nTotal Expense:", total)

    category_summary = df.groupby("Category")["Amount"].sum()

    print("\nCategory Wise Spending:")
    print(category_summary)


def show_chart():
    df = pd.read_csv(FILE_NAME)

    if df.empty:
        print("No data available for chart.")
        return

    category_summary = df.groupby("Category")["Amount"].sum()

    category_summary.plot(kind="pie", autopct='%1.1f%%')

    plt.title("Expense Distribution")
    plt.ylabel("")
    plt.show()


def budget_planner():
    df = pd.read_csv(FILE_NAME)

    if df.empty:
        print("No expenses recorded.")
        return

    budget = float(input("Enter your monthly budget: "))

    total = df["Amount"].sum()

    print("Total spending:", total)

    if total > budget:
        print("You exceeded your budget!")
    else:
        print("You are within your budget.")


def export_data():
    df = pd.read_csv(FILE_NAME)

    df.to_excel("expenses_export.xlsx", index=False)

    print("Data exported to expenses_export.xlsx")


def menu():

    while True:

        print("\n====== Expense Tracker ======")
        print("1. Add Expense")
        print("2. View Expenses")
        print("3. Delete Expense")
        print("4. Generate Report")
        print("5. Show Chart")
        print("6. Budget Planner")
        print("7. Export Data")
        print("8. Exit")

        choice = input("Enter your choice: ")

        if choice == "1":
            add_expense()

        elif choice == "2":
            view_expenses()

        elif choice == "3":
            delete_expense()

        elif choice == "4":
            generate_report()

        elif choice == "5":
            show_chart()

        elif choice == "6":
            budget_planner()

        elif choice == "7":
            export_data()

        elif choice == "8":
            print("Goodbye!")
            break

        else:
            print("Invalid choice.")


menu()
# Out:
# ====== Expense Tracker ======
# 1. Add Expense
# 2. View Expenses
# 3. Delete Expense
# 4. Generate Report
# 5. Show Chart
# 6. Budget Planner
# 7. Export Data
# 8. Exit
# Enter your choice:  3000
# Invalid choice.
#
# ====== Expense Tracker ======
# 1. Add Expense
# 2. View Expenses
# 3. Delete Expense
# 4. Generate Report
# 5. Show Chart
# 6. Budget Planner
# 7. Export Data
# 8. Exit
# Enter your choice:  1
# Enter date (YYYY-MM-DD):  2026-03-12
# Enter category (Food, Travel, Shopping, etc):  food
# Enter amount:  3000
# Enter description:  party
# C:\Users\khaja\AppData\Local\Temp\ipykernel_7880\2550134363.py:29: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, new_expense], ignore_index=True)
# Expense added successfully!
#
# ====== Expense Tracker ======
# 1. Add Expense
# 2. View Expenses
# 3. Delete Expense
# 4. Generate Report
# 5. Show Chart
# 6. Budget Planner
# 7. Export Data
# 8. Exit
# Enter your choice:  2
# All Expenses
#          Date Category  Amount Description
# 0  2026-03-12     food  3000.0       party
#
# ====== Expense Tracker ======
# 1. Add Expense
# 2. View Expenses
# 3. Delete Expense
# 4. Generate Report
# 5. Show Chart
# 6. Budget Planner
# 7. Export Data
# 8. Exit
# Enter your choice:  4
# Total Expense: 3000.0
#
# Category Wise Spending:
# Category
# food    3000.0
# Name: Amount, dtype: float64
#
# ====== Expense Tracker ======
# 1. Add Expense
# 2. View Expenses
# 3. Delete Expense
# 4. Generate Report
# 5. Show Chart
# 6. Budget Planner
# 7. Export Data
# 8. Exit
# Enter your choice:  8
# Goodbye!
